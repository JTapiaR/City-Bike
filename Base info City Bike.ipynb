# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import unicodecsv as csv
from io import BytesIO
f = BytesIO()
w = csv.writer(f, encoding='utf-8')
_ = w.writerow((u'é', u'ñ'))
_ = f.seek(0)
r = csv.reader(f, encoding='utf-8')
next(r) == [u'é', u'ñ']
True
# Out:
# True

# %%
import glob
glob.glob("C:/Users/JESICA/Downloads/Viajes City Bike/2013*.csv")
# Out:
# ['C:/Users/JESICA/Downloads/Viajes City Bike\\2013-07 - Citi Bike trip data.csv',
#  'C:/Users/JESICA/Downloads/Viajes City Bike\\2013-08 - Citi Bike trip data.csv',
#  'C:/Users/JESICA/Downloads/Viajes City Bike\\2013-09 - Citi Bike trip data.csv',
#  'C:/Users/JESICA/Downloads/Viajes City Bike\\2013-10 - Citi Bike trip data.csv',
#  'C:/Users/JESICA/Downloads/Viajes City Bike\\2013-11 - Citi Bike trip data.csv',
#  'C:/Users/JESICA/Downloads/Viajes City Bike\\2013-12 - Citi Bike trip data.csv',
#  'C:/Users/JESICA/Downloads/Viajes City Bike\\201306-citibike-tripdata.csv']

# %%
citybike2013=pd.DataFrame()
for x in glob.glob("C:/Users/JESICA/Downloads/Viajes City Bike/2013*.csv"):
    df=pd.read_csv(x,sep = ',', encoding="utf-8-sig")
    citybike2013=citybike2013.append(df,ignore_index=True)

# %%
citybike2013
# Out:
#          tripduration            starttime             stoptime  \
# 0                 634  2013-07-01 00:00:00  2013-07-01 00:10:34
# 1                1547  2013-07-01 00:00:02  2013-07-01 00:25:49
# 2                 178  2013-07-01 00:01:04  2013-07-01 00:04:02
# 3                1580  2013-07-01 00:01:06  2013-07-01 00:27:26
# 4                 757  2013-07-01 00:01:10  2013-07-01 00:13:47
# 5                 861  2013-07-01 00:01:23  2013-07-01 00:15:44
# 6                 550  2013-07-01 00:01:59  2013-07-01 00:11:09
# 7                 288  2013-07-01 00:02:16  2013-07-01 00:07:04
# 8                 766  2013-07-01 00:02:16  2013-07-01 00:15:02
# 9                 773  2013-07-01 00:02:23  2013-07-01 00:15:16
# 10                456  2013-07-01 00:02:23  2013-07-01 00:09:59
# 11                632  2013-07-01 00:02:24  2013-07-01 00:12:56
# 12                623  2013-07-01 00:02:24  2013-07-01 00:12:47
# 13                228  2013-07-01 00:02:33  2013-07-01 00:06:21
# ...

# %%
citybike2013.to_excel("citybike2013.xlsx")

# %%
citybike2014=pd.DataFrame()
for x in glob.glob("C:/Users/JESICA/Downloads/Viajes City Bike/2014*.csv"):
    df=pd.read_csv(x,sep = ',', encoding="utf-8-sig")
    citybike2014=citybike2014.append(df,ignore_index=True)

# %%
citybike2014.to_excel("citybike2014.xlsx")

# %%
citybike2015=pd.DataFrame()
for x in glob.glob("C:/Users/JESICA/Downloads/Viajes City Bike/2015*.csv"):
    df=pd.read_csv(x,sep = ',', encoding="utf-8-sig")
    citybike2015=citybike2015.append(df,ignore_index=True)

# %%
citybike2015.to_excel("citybike2015.xlsx")

# %%
citybike2016=pd.DataFrame()
for x in glob.glob("C:/Users/JESICA/Downloads/Viajes City Bike/2016*.csv"):
    df=pd.read_csv(x,sep = ',', encoding="utf-8-sig")
    citybike2016=citybike2016.append(df,ignore_index=True)
# Out:
# C:\Users\JESICA\Anaconda3.5\envs\gdal_env\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
citybike2016.to_excel("citybike2016.xlsx")

# %%
citybike2017=pd.DataFrame()
for x in glob.glob("C:/Users/JESICA/Downloads/Viajes City Bike/2017*.csv"):
    df=pd.read_csv(x,sep = ',', encoding="utf-8-sig")
    citybike2017=citybike2017.append(df,ignore_index=True)

# %%
citybike2017.to_excel("citybike2017.xlsx")

# %%
citybike2018=pd.DataFrame()
for x in glob.glob("C:/Users/JESICA/Downloads/Viajes City Bike/2018*.csv"):
    df=pd.read_csv(x,sep = ',', encoding="utf-8-sig")
    citybike2018=citybike2018.append(df,ignore_index=True)

# %%
citybike2018.to_excel("citybike2018.xlsx")

# %%
citybike2019=pd.DataFrame()
for x in glob.glob("C:/Users/JESICA/Downloads/Viajes City Bike/2019*.csv"):
    df=pd.read_csv(x,sep = ',', encoding="utf-8-sig")
    citybike2019=citybike2019.append(df,ignore_index=True)

# %%
citybike2019.to_excel("citybike2019.xlsx")

# %%
import glob
glob.glob("C:/Users/JESICA/citybike20*.xlsx")
# Out:
# ['C:/Users/JESICA\\citybike2013.xlsx',
#  'C:/Users/JESICA\\citybike2014.xlsx',
#  'C:/Users/JESICA\\citybike2015.xlsx',
#  'C:/Users/JESICA\\citybike2016.xlsx',
#  'C:/Users/JESICA\\citybike2017.xlsx',
#  'C:/Users/JESICA\\citybike2018.xlsx',
#  'C:/Users/JESICA\\citybike2019.xlsx']

# %%
citybikeall=pd.DataFrame()
for x in glob.glob("C:/Users/JESICA/citybike20*.xlsx"):
    df=pd.read_excel(x,sep = ',', encoding="utf-8-sig")
    citybikeall=citybikeall.append(df,ignore_index=True)
